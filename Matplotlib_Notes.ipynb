# %% [markdown]
# <a href="https://colab.research.google.com/github/ebuillent13yadav/Matplotlib_Notes/blob/main/Matplotlib_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Line Plot

# %%
x = np.array([2023, 2024, 2025, 2026])
y1 = np.array([15, 25, 30, 20])
y2 = np.array([17, 23, 38, 5])
y3 = np.array([13, 15, 20, 30])

plt.title("Class Size", fontsize=20, fontweight="bold", color="#2d4cfc")

plt.xlabel("Year", fontsize=20, fontweight="bold", color="#2dbefc")
plt.ylabel("Students", fontsize=20, fontweight="bold", color="#2dbefc")

line_style = dict(marker=".",
         markersize=20,
         markerfacecolor="#1cd3fc",
         markeredgecolor="r",
         linestyle="solid",
         linewidth=3,)

plt.tick_params(axis="both", colors="#2d4cfc")

plt.plot(x, y1, color="#48814A", **line_style)
plt.plot(x, y2, color="#3B3361", **line_style)
plt.plot(x, y3, color="#DE823C", **line_style)

plt.xticks(x)

plt.show()

# %% [markdown]
# # Grid Lines

# %%
x = [1, 2, 3, 4, 5]
y = [5, 10, 15, 20, 25]

plt.grid(axis="y",
         linewidth=2,
         color="lightgray",
         linestyle="dashed")

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Bar Chart

# %%
categories = np.array(["Grains", "Fruits", "Vegetables", "Protein", "Dairy", "Sweets"])
values = np.array([4, 3, 2, 5, 3, 1])

plt.title("Daily Consumption")
plt.xlabel("Food")
plt.ylabel("Quantity")

plt.bar(categories, values, color="skyblue", alpha=0.4)
# plt.barh(categories, values, color="skyblue")
plt.show()

# %% [markdown]
# # Pie Charts

# %%
categories = np.array(["Freshmen", "Sophomores", "Juniors", "Seniors"])
values = np.array([300, 250, 275, 225])
colors = ["red", "yellow", "blue", "green"]

plt.pie(values, labels=categories,
        autopct="%1.1f%%",
        colors=colors,
        explode=[0.2, 0, 0, 0.1],
        shadow=True,
        startangle=90)

plt.title("Bro Code College")
plt.show()

# %% [markdown]
# # Scatter Plot
